# %%
# Cell 1: Install dependencies (run once)
# Cell 1: Install everything fresh
# !pip install gymnasium ale-py autorom
# Out:
# Requirement already satisfied: gymnasium in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (1.2.3)
# Requirement already satisfied: ale-py in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (0.11.2)
# Requirement already satisfied: autorom in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (0.6.1)
# Requirement already satisfied: numpy>=1.21.0 in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from gymnasium) (2.1.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from gymnasium) (3.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from gymnasium) (4.12.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: click in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from autorom) (8.1.8)
# Requirement already satisfied: requests in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from autorom) (2.32.3)
# Requirement already satisfied: colorama in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from click->autorom) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from requests->autorom) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from requests->autorom) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from requests->autorom) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\sspindt\appdata\local\anaconda3\lib\site-packages (from requests->autorom) (2025.4.26)

# %%
# Cell 2: Accept and install the Atari ROMs
# !AutoROM --accept-license
# Out:
# AutoROM will download the Atari 2600 ROMs.
# They will be installed to:
# 	C:\Users\sspindt\AppData\Local\anaconda3\Lib\site-packages\AutoROM\roms
#
# Existing ROMs will be overwritten.

# %%
# Cell 3: Play Frogger
import ale_py
import gymnasium as gym

gym.register_envs(ale_py)  # explicitly registers ALE environments

env = gym.make("ALE/Frogger-v5", render_mode="human")
obs, info = env.reset(seed=42)

while True:
    action = env.action_space.sample()
    obs, reward, terminated, truncated, info = env.step(action)
    if terminated or truncated:
        obs, info = env.reset()

env.close()
